# %%
import pandas as pd

# %%
import numpy as np

# %%
dfplay1 = pd.read_csv("googleplaystore.csv")

# %%
dfplay1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
dfplay1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
dfplay1.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
dfplay1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Univariate Analysis

dfplay1['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
dfplay1['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
dfplay1['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
dfplay1['Reviews']
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
dfplay1['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10841, dtype: object

# %%
dfplay1['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
dfplay1['Type']
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 10841, dtype: object

# %%
dfplay1['Price']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10836    0
# 10837    0
# 10838    0
# 10839    0
# 10840    0
# Name: Price, Length: 10841, dtype: object

# %%
dfplay1['Content Rating']
# Out:
# 0          Everyone
# 1          Everyone
# 2          Everyone
# 3              Teen
# 4          Everyone
#             ...
# 10836      Everyone
# 10837      Everyone
# 10838      Everyone
# 10839    Mature 17+
# 10840      Everyone
# Name: Content Rating, Length: 10841, dtype: object

# %%
dfplay1['Genres']
# Out:
# 0                     Art & Design
# 1        Art & Design;Pretend Play
# 2                     Art & Design
# 3                     Art & Design
# 4          Art & Design;Creativity
#                    ...
# 10836                    Education
# 10837                    Education
# 10838                      Medical
# 10839            Books & Reference
# 10840                    Lifestyle
# Name: Genres, Length: 10841, dtype: object

# %%
dfplay1['Last Updated']
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10841, dtype: object

# %%
dfplay1['Current Ver']
# Out:
# 0                     1.0.0
# 1                     2.0.0
# 2                     1.2.4
# 3        Varies with device
# 4                       1.1
#                 ...
# 10836                  1.48
# 10837                   1.0
# 10838                   1.0
# 10839    Varies with device
# 10840    Varies with device
# Name: Current Ver, Length: 10841, dtype: object

# %%
dfplay1['Android Ver']
# Out:
# 0              4.0.3 and up
# 1              4.0.3 and up
# 2              4.0.3 and up
# 3                4.2 and up
# 4                4.4 and up
#                 ...
# 10836            4.1 and up
# 10837            4.1 and up
# 10838            2.2 and up
# 10839    Varies with device
# 10840    Varies with device
# Name: Android Ver, Length: 10841, dtype: object

# %%
dfplay1.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
dfplay1['App'].value_counts()
# Out:
# ROBLOX                                               9
# CBS Sports App - Scores, News, Stats & Watch Live    8
# Duolingo: Learn Languages Free                       7
# ESPN                                                 7
# Candy Crush Saga                                     7
#                                                     ..
# ARuler - AR Ruler app, Measure tools                 1
# Downtown Mafia: Gang Wars (Mobster Game) Free        1
# Cheat Codes for GTA V                                1
# Keyboard - wallpapers , photos                       1
# Simple x3DS Emulator - BETA                          1
# Name: App, Length: 9660, dtype: int64

# %%
pd.set_option("display.max_rows", 20, "display.max_columns", 20)

# %%
dfplay1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
dfplay1 = pd.read_csv("C:\\Users\\Pinak\\Desktop\\Python\\googleplaystore.csv",na_values=['Varies with device'])

# %%
dfplay1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver       1467
# Android Ver       1365
# dtype: int64

# %%
dfplay1['Reviews'].value_counts()
# Out:
# 0         596
# 1         272
# 2         214
# 3         175
# 4         137
#          ...
# 1011        1
# 3268        1
# 218881      1
# 10658       1
# 14123       1
# Name: Reviews, Length: 6002, dtype: int64

# %% [markdown]
# # ## Correcting Incorrect Dtypes :

# %%
dfplay1['junk_in_Reviews'] = dfplay1['Reviews'].str.isnumeric()

# %%
dfplay1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
dfplay1['junk_in_Reviews'].value_counts()
# Out:
# True     10840
# False        1
# Name: junk_in_Reviews, dtype: int64

# %%
dfplay1[dfplay1["junk_in_Reviews"] == False]   ## used ==False as value was created using logic , 
                                               ## if it was string then should have given =="False"
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver  junk_in_Reviews
# 10472       1.0.19  4.0 and up         NaN            False

# %%
dfplay1.drop(index=10472,inplace=True)  ## Dropped the index as only 1 value found of non integer value

# %%
dfplay1['junk_in_Reviews'].value_counts()
# Out:
# True    10840
# Name: junk_in_Reviews, dtype: int64

# %%
dfplay1['Reviews'] = dfplay1['Reviews'].astype(int)  ## Converted Reviwes to Integer as now string value is removed

# %%
dfplay1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   App              10840 non-null  object
#  1   Category         10840 non-null  object
#  2   Rating           9366 non-null   float64
#  3   Reviews          10840 non-null  int32
#  4   Size             9145 non-null   object
#  5   Installs         10840 non-null  object
#  6   Type             10839 non-null  object
#  7   Price            10840 non-null  object
#  8   Content Rating   10840 non-null  object
#  9   Genres           10840 non-null  object
#  10  Last Updated     10840 non-null  object
#  11  Current Ver      9373 non-null   object
#  12  Android Ver      9476 non-null   object
#  13  junk_in_Reviews  10840 non-null  bool
# dtypes: bool(1), float64(1), int32(1), object(11)
# memory usage: 1.1+ MB

# %%
dfplay1.drop(columns = 'junk_in_Reviews',inplace = True)  ## Removed junk_in_Reviews column as its not needed anymore

# %%
dfplay1['Price'].value_counts()
# Out:
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.40        1
# $15.46        1
# $3.90         1
# $37.99        1
# $2.95         1
# Name: Price, Length: 92, dtype: int64

# %%
dfplay1['Price'] = dfplay1['Price'].str.replace('$', '')

# %%
dfplay1['Price'] = dfplay1['Price'].astype(float)

# %%
dfplay1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     9373 non-null   object
#  12  Android Ver     9476 non-null   object
# dtypes: float64(2), int32(1), object(10)
# memory usage: 1.1+ MB

# %%
dfplay1['Installs'] = dfplay1['Installs'].str.replace('+', '')
dfplay1['Installs'] = dfplay1['Installs'].str.replace(',', '')

# %%
dfplay1['Installs'] = dfplay1['Installs'].astype(int)

# %%
dfplay1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   object
#  5   Installs        10840 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     9373 non-null   object
#  12  Android Ver     9476 non-null   object
# dtypes: float64(2), int32(2), object(9)
# memory usage: 1.1+ MB

# %%
pd.set_option("display.max_rows", 20, "display.max_columns", 20)

# %%
dfplay1['Size'].value_counts()
# Out:
# 11M     198
# 12M     196
# 14M     194
# 13M     191
# 15M     184
#        ...
# 414k      1
# 713k      1
# 459k      1
# 562k      1
# 992k      1
# Name: Size, Length: 460, dtype: int64

# %% [markdown]
# # Treating Size Column

# %%
s = dfplay1['Size']

dfplay1['Size'] = s.str.extract('(\d+)').astype(float).\
mask(s.str.contains('M', na = False), lambda x: x * 1000)

# %%
dfplay1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
dfplay1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     9373 non-null   object
#  12  Android Ver     9476 non-null   object
# dtypes: float64(3), int32(2), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Treating Null Values

# %%
dfplay1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver       1467
# Android Ver       1364
# dtype: int64

# %%
dfplay1['Rating'].max()
# Out:
# 5.0

# %%
dfplay1['Rating'].describe()
# Out:
# count    9366.000000
# mean        4.191757
# std         0.515219
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfplay1['Rating'].median()
# Out:
# 4.3

# %%
sns.set(rc={'figure.figsize':(20,14)})

# %%
sns.boxplot(dfplay1['Rating'],orient='v')

# %%
dfplay1.quantile(q=[.25,.5,.75,.9,.99],axis=0)
# Out:
#       Rating     Reviews     Size     Installs  Price
# 0.25     4.0       38.00   4000.0       1000.0   0.00
# 0.50     4.3     2094.00  13000.0     100000.0   0.00
# 0.75     4.5    54775.50  30000.0    5000000.0   0.00
# 0.90     4.7   464993.10  55000.0   10000000.0   0.00
# 0.99     5.0  8922753.96  96000.0  500000000.0   9.99

# %%
dfplay1[dfplay1['Rating']>=4.5].shape
# Out:
# (2955, 13)

# %%
dfplay1 = dfplay1.fillna({'Rating' : dfplay1['Rating'].median()})

# %%
sns.boxplot(dfplay1['Rating'],orient='v')

# %%
sns.boxplot(dfplay1['Size'],orient='v')

# %%
dfplay1 = dfplay1.fillna({'Size' : dfplay1['Size'].median()})

# %%
sns.boxplot(dfplay1['Size'],orient='v')

# %%
dfplay1.quantile(q=[.25,.5,.75,.9,.99],axis=0)
# Out:
#       Rating     Reviews     Size     Installs  Price
# 0.25     4.1       38.00   5000.0       1000.0   0.00
# 0.50     4.3     2094.00  13000.0     100000.0   0.00
# 0.75     4.5    54775.50  26000.0    5000000.0   0.00
# 0.90     4.7   464993.10  50000.0   10000000.0   0.00
# 0.99     5.0  8922753.96  96000.0  500000000.0   9.99

# %%
dfplay1['Android Ver'].value_counts()
# Out:
# 4.1 and up       2451
# 4.0.3 and up     1501
# 4.0 and up       1375
# 4.4 and up        980
# 2.3 and up        652
# 5.0 and up        601
# 4.2 and up        394
# 2.3.3 and up      281
# 2.2 and up        244
# 4.3 and up        243
# 3.0 and up        241
# 2.1 and up        134
# 1.6 and up        116
# 6.0 and up         60
# 7.0 and up         42
# 3.2 and up         36
# 2.0 and up         32
# 5.1 and up         24
# 1.5 and up         20
# 4.4W and up        12
# 3.1 and up         10
# 2.0.1 and up        7
# 8.0 and up          6
# 7.1 and up          3
# 1.0 and up          2
# 4.0.3 - 7.1.1       2
# 5.0 - 8.0           2
# 5.0 - 6.0           1
# 5.0 - 7.1.1         1
# 4.1 - 7.1.1         1
# 2.2 - 7.1.1         1
# 7.0 - 7.1.1         1
# Name: Android Ver, dtype: int64

# %%
dfplay1['Android Ver'].isnull().sum()
# Out:
# 1364

# %%
dfplay1['Android Ver'].mode()
# Out:
# 0    4.1 and up
# dtype: object

# %%
dfplay1['Current Ver'].mode()
# Out:
# 0    1.0
# dtype: object

# %%
dfplay1['Current Ver'].value_counts()
# Out:
# 1.0            809
# 1.1            264
# 1.2            178
# 2.0            151
# 1.3            145
#               ...
# 3.3.7z           1
# 2018.5.25        1
# 2.1.10 (49)      1
# 6.2-pro          1
# 4.0.8552         1
# Name: Current Ver, Length: 2830, dtype: int64

# %%
dfplay1['Current Ver'].value_counts()
# Out:
# 1.0            809
# 1.1            264
# 1.2            178
# 2.0            151
# 1.3            145
#               ...
# 3.3.7z           1
# 2018.5.25        1
# 2.1.10 (49)      1
# 6.2-pro          1
# 4.0.8552         1
# Name: Current Ver, Length: 2830, dtype: int64

# %%
dfplay1[dfplay1["Current Ver"] == '1255162018']
# Out:
#                App           Category  Rating  Reviews     Size  Installs  \
# 5023  Dashboard AE  AUTO_AND_VEHICLES     4.3        0  13000.0        10
#
#       Type  Price Content Rating           Genres  Last Updated Current Ver  \
# 5023  Free    0.0       Everyone  Auto & Vehicles  May 16, 2018  1255162018
#
#      Android Ver
# 5023  6.0 and up

# %%
dfplay1.drop(index=5023,inplace=True)

# %%
dfplay1[dfplay1["Current Ver"] == '1255162018']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
dfplay1['Current Ver'].value_counts()
# Out:
# 1.0            809
# 1.1            264
# 1.2            178
# 2.0            151
# 1.3            145
#               ...
# 1.5.49           1
# 3.3.7z           1
# 2018.5.25        1
# 2.1.10 (49)      1
# 4.0.8552         1
# Name: Current Ver, Length: 2829, dtype: int64

# %%
dfplay1['Price'].value_counts()
# Out:
# 0.00    10039
# 0.99      148
# 2.99      129
# 1.99       73
# 4.99       72
#         ...
# 1.20        1
# 1.59        1
# 2.56        1
# 1.61        1
# 1.04        1
# Name: Price, Length: 92, dtype: int64

# %%
dfplay1['Current Ver'].isnull().sum()
# Out:
# 1467

# %%
dfplay1[dfplay1['Current Ver'].isna()]
# Out:
#                                                  App             Category  \
# 3                              Sketch - Draw & Paint       ART_AND_DESIGN
# 15                   Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 37                                Floor Plan Creator       ART_AND_DESIGN
# 42                        Textgram - write on photos       ART_AND_DESIGN
# 52                     Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# ...                                              ...                  ...
# 10725                                      Posta App  MAPS_AND_NAVIGATION
# 10765                Chat For Strangers - Video Chat               SOCIAL
# 10826      Frim: get new friends on local chat rooms               SOCIAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
dfplay1['Current Ver'].isnull().sum()
# Out:
# 1467

# %%
dfplay1=dfplay1.fillna({"Current Ver":"1.0"})

# %%
dfplay1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
dfplay1=dfplay1.fillna({"Android Ver":"4.1 and up"})

# %%
dfplay1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
dfplay1[dfplay1['Type'].isna()]
# Out:
#                             App Category  Rating  Reviews     Size  Installs  \
# 9148  Command & Conquer: Rivals   FAMILY     4.3        0  13000.0         0
#
#      Type  Price Content Rating    Genres   Last Updated Current Ver  \
# 9148  NaN    0.0   Everyone 10+  Strategy  June 28, 2018         1.0
#
#      Android Ver
# 9148  4.1 and up

# %%
dfplay1=dfplay1.fillna({"Type":"Free"}) ## imputed null values as per price

# %%
dfplay1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ## Correcting of Incorrect values of Reviews

# %%
 dfplay1[(dfplay1['Reviews']) > (dfplay1['Installs'])]
# Out:
#                                      App         Category  Rating  Reviews  \
# 2454                 KBA-EZ Health Guide          MEDICAL     5.0        4
# 4550   RMEduS - 음성인식을 활용한 R 프로그래밍 실습 시스템           FAMILY     4.3        4
# 4663       Alarmy (Sleep If U Can) - Pro        LIFESTYLE     4.8    10249
# 5812             AX Watch for WatchMaker  PERSONALIZATION     4.3        2
# 5917                            Ra Ga Ba             GAME     5.0        2
# 6508                          Sam.BN Pro            TOOLS     4.3       11
# 6700                    Brick Breaker BR             GAME     5.0        7
# 7402                Trovami se ci riesci             GAME     5.0       11
# 8591                             DN Blog           SOCIAL     5.0       20
# 9096                           DZ Puzzle           FAMILY     4.3       14
# 10697                            Mu.F.O.             GAME     5.0        2
#
# ...

# %%
 dfplay1[(dfplay1['Reviews']) > (dfplay1['Installs'])].shape
# Out:
# (11, 13)

# %%
dfplay1['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# Name: Type, dtype: int64

# %%
A=(dfplay1['Type'] == 'Free') & (dfplay1['Price'] != 0.00)

# %%
A.value_counts()
# Out:
# False    10839
# dtype: int64

# %%
dfplay1['Correct_reviews'] = np.where(dfplay1['Reviews'] > dfplay1['Installs'] , 'Incorrect' , 'Correct')

# %%
dfplay1['Correct_reviews'].value_counts()
# Out:
# Correct      10828
# Incorrect       11
# Name: Correct_reviews, dtype: int64

# %%
dfplay1[dfplay1["Correct_reviews"] == 'Incorrect']
# Out:
#                                      App         Category  Rating  Reviews  \
# 2454                 KBA-EZ Health Guide          MEDICAL     5.0        4
# 4550   RMEduS - 음성인식을 활용한 R 프로그래밍 실습 시스템           FAMILY     4.3        4
# 4663       Alarmy (Sleep If U Can) - Pro        LIFESTYLE     4.8    10249
# 5812             AX Watch for WatchMaker  PERSONALIZATION     4.3        2
# 5917                            Ra Ga Ba             GAME     5.0        2
# 6508                          Sam.BN Pro            TOOLS     4.3       11
# 6700                    Brick Breaker BR             GAME     5.0        7
# 7402                Trovami se ci riesci             GAME     5.0       11
# 8591                             DN Blog           SOCIAL     5.0       20
# 9096                           DZ Puzzle           FAMILY     4.3       14
# 10697                            Mu.F.O.             GAME     5.0        2
#
# ...

# %%
dfplay1['Reviews'] = np.where(dfplay1['Correct_reviews'] == 'Incorrect', dfplay1['Installs'], dfplay1['Reviews'])

# %%
dfplay1[dfplay1["Correct_reviews"] == 'Incorrect']
# Out:
#                                      App         Category  Rating  Reviews  \
# 2454                 KBA-EZ Health Guide          MEDICAL     5.0        1
# 4550   RMEduS - 음성인식을 활용한 R 프로그래밍 실습 시스템           FAMILY     4.3        1
# 4663       Alarmy (Sleep If U Can) - Pro        LIFESTYLE     4.8    10000
# 5812             AX Watch for WatchMaker  PERSONALIZATION     4.3        1
# 5917                            Ra Ga Ba             GAME     5.0        1
# 6508                          Sam.BN Pro            TOOLS     4.3       10
# 6700                    Brick Breaker BR             GAME     5.0        5
# 7402                Trovami se ci riesci             GAME     5.0       10
# 8591                             DN Blog           SOCIAL     5.0       10
# 9096                           DZ Puzzle           FAMILY     4.3       10
# 10697                            Mu.F.O.             GAME     5.0        1
#
# ...

# %%
dfplay1.drop(columns = 'Correct_reviews',inplace = True)

# %%
dfplay1['Price'] = np.where(dfplay1['Price'] == 0 , 0.00 , dfplay1['Price'])

# %%
dfplay1['Price'].value_counts()
# Out:
# 0.00    10039
# 0.99      148
# 2.99      129
# 1.99       73
# 4.99       72
#         ...
# 1.20        1
# 1.59        1
# 2.56        1
# 1.61        1
# 1.04        1
# Name: Price, Length: 92, dtype: int64

# %% [markdown]
# ## Checking Incorrect pricing of Free Apps :

# %%
dfplay1['Correct_Price'] = np.where((dfplay1['Type'] == 'Free') & (dfplay1['Price'] != 0.00 ) , 'Incorrect' , 'Correct')

# %%
dfplay1['Correct_Price'].value_counts()
# Out:
# Correct    10839
# Name: Correct_Price, dtype: int64

# %%
dfplay1.drop(columns = 'Correct_Price',inplace = True)

# %%
dfplay1.describe(include='all')
# Out:
#            App Category        Rating       Reviews           Size  \
# count    10839    10839  10839.000000  1.083900e+04   10839.000000
# unique    9658       33           NaN           NaN            NaN
# top     ROBLOX   FAMILY           NaN           NaN            NaN
# freq         9     1972           NaN           NaN            NaN
# mean       NaN      NaN      4.206467  4.441938e+05   20035.710121
# std        NaN      NaN      0.480363  2.927893e+06   21087.428035
# min        NaN      NaN      1.000000  0.000000e+00       8.000000
# 25%        NaN      NaN      4.100000  3.800000e+01    5000.000000
# 50%        NaN      NaN      4.300000  2.094000e+03   13000.000000
# 75%        NaN      NaN      4.500000  5.478300e+04   26000.000000
# max        NaN      NaN      5.000000  7.815831e+07  100000.000000
#
#             Installs   Type         Price Content Rating Genres  \
# count   1.083900e+04  10839  10839.000000          10839  10839
# ...

# %%
dfplay1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10839 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  int32
#  4   Size            10839 non-null  float64
#  5   Installs        10839 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  float64
#  8   Content Rating  10839 non-null  object
#  9   Genres          10839 non-null  object
#  10  Last Updated    10839 non-null  object
#  11  Current Ver     10839 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(3), int32(2), object(8)
# memory usage: 1.1+ MB

# %%
 dfplay1[(dfplay1['Price']>200) & (dfplay1['Price']<500)]
# Out:
#                                     App   Category  Rating  Reviews     Size  \
# 4197             most expensive app (H)     FAMILY     4.3        6   1000.0
# 4362                         💎 I'm rich  LIFESTYLE     3.8      718  26000.0
# 4367           I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7000.0
# 5351                          I am rich  LIFESTYLE     3.8     3547   1000.0
# 5354                     I am Rich Plus     FAMILY     4.0      856   8000.0
# 5355                      I am rich VIP  LIFESTYLE     3.8      411   2000.0
# 5356                  I Am Rich Premium    FINANCE     4.1     1867   4000.0
# 5357                I am extremely Rich  LIFESTYLE     2.9       41   2000.0
# 5358                         I am Rich!    FINANCE     3.8       93  22000.0
# 5359                 I am rich(premium)    FINANCE     3.5      472    965.0
# 5362                      I Am Rich Pro     FAMILY     4.4      201   2000.0
# ...

# %%
 dfplay1[(dfplay1['Price']>500) & (dfplay1['Price']<1000)]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
dfplay1['Reviews'].max()
# Out:
# 78158306

# %%
 dfplay1[(dfplay1['Reviews']>50000000) & (dfplay1['Reviews']<78158308)]
# Out:
#                                            App       Category  Rating  \
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 336                         WhatsApp Messenger  COMMUNICATION     4.4
# 381                         WhatsApp Messenger  COMMUNICATION     4.4
# 382   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 2544                                  Facebook         SOCIAL     4.1
# 2545                                 Instagram         SOCIAL     4.5
# 2604                                 Instagram         SOCIAL     4.5
# 2611                                 Instagram         SOCIAL     4.5
# 3904                        WhatsApp Messenger  COMMUNICATION     4.4
# 3909                                 Instagram         SOCIAL     4.5
# 3943                                  Facebook         SOCIAL     4.1
# 4104  Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
#
# ...

# %%
 dfplay1[(dfplay1['Reviews']>20000000) & (dfplay1['Reviews']<50000000)]
# Out:
#                                                     App       Category  \
# 1654                                     Subway Surfers           GAME
# 1655                                   Candy Crush Saga           GAME
# 1660                                       Clash Royale           GAME
# 1670                                     Clash of Clans           GAME
# 1700                                     Subway Surfers           GAME
# 1704                                     Clash of Clans           GAME
# 1705                                   Candy Crush Saga           GAME
# 1721                                       Clash Royale           GAME
# 1750                                     Subway Surfers           GAME
# 1751                                   Candy Crush Saga           GAME
# 1842                                   Candy Crush Saga           GAME
# 1869                                   Candy Crush Saga           GAME
# ...

# %%
 dfplay1[(dfplay1['Reviews']>10000000) & (dfplay1['Reviews']<20000000)]
# Out:
#                                                     App            Category  \
# 342                                     Viber Messenger       COMMUNICATION
# 378         UC Browser - Fast Download Private & Secure       COMMUNICATION
# 385                                     Viber Messenger       COMMUNICATION
# 391                       Skype - free IM & video calls       COMMUNICATION
# 403                         LINE: Free Calls & Messages       COMMUNICATION
# 406                         BBM - Free Calls & Messages       COMMUNICATION
# 420         UC Browser - Fast Download Private & Secure       COMMUNICATION
# 431                                     Viber Messenger       COMMUNICATION
# 467                                     Viber Messenger       COMMUNICATION
# 468                       Skype - free IM & video calls       COMMUNICATION
# 474                         LINE: Free Calls & Messages       COMMUNICATION
# ...

# %%
dfplay1[(dfplay1['Reviews']>20000000)]
# Out:
#                                                     App       Category  \
# 335            Messenger – Text and Video Chat for Free  COMMUNICATION
# 336                                  WhatsApp Messenger  COMMUNICATION
# 381                                  WhatsApp Messenger  COMMUNICATION
# 382            Messenger – Text and Video Chat for Free  COMMUNICATION
# 1654                                     Subway Surfers           GAME
# 1655                                   Candy Crush Saga           GAME
# 1660                                       Clash Royale           GAME
# 1670                                     Clash of Clans           GAME
# 1700                                     Subway Surfers           GAME
# 1704                                     Clash of Clans           GAME
# 1705                                   Candy Crush Saga           GAME
# 1721                                       Clash Royale           GAME
# ...

# %% [markdown]
# ## Treating High values of columns as such high values are mostly junk

# %%
dfplay1['High_reviews'] = np.where(dfplay1['Reviews']>20000000 , 'High' , 'Normal')

# %%
 V = dfplay1[(dfplay1['Reviews']>20000000)]

# %%
V['Rating'].value_counts()
# Out:
# 4.4    10
# 4.5    10
# 4.6     8
# 4.0     3
# 4.7     2
# 4.3     2
# 4.1     2
# Name: Rating, dtype: int64

# %%
dfplay1['Genres'].value_counts()
# Out:
# Tools                                  842
# Entertainment                          623
# Education                              549
# Medical                                463
# Business                               460
#                                       ...
# Health & Fitness;Action & Adventure      1
# Arcade;Pretend Play                      1
# Strategy;Education                       1
# Trivia;Education                         1
# Lifestyle;Pretend Play                   1
# Name: Genres, Length: 119, dtype: int64

# %%
dfplay1['High_reviews'].value_counts()
# Out:
# Normal    10802
# High         37
# Name: High_reviews, dtype: int64

# %%
filter_list = [4.4 , 4.5 , 4.6 , 4.0 , 4.7 , 4.3 , 4.1 ]

# %%
dfplay1[dfplay1.Rating.isin(filter_list)].median()
# Out:
# Rating           4.3
# Reviews       4385.0
# Size         13000.0
# Installs    100000.0
# Price            0.0
# dtype: float64

# %%
dfplay1['Reviews'] = np.where(dfplay1['High_reviews'] == 'High', 4385, dfplay1['Reviews'])

# %%
dfplay1[dfplay1['High_reviews'] == 'High']
# Out:
#                                                     App       Category  \
# 335            Messenger – Text and Video Chat for Free  COMMUNICATION
# 336                                  WhatsApp Messenger  COMMUNICATION
# 381                                  WhatsApp Messenger  COMMUNICATION
# 382            Messenger – Text and Video Chat for Free  COMMUNICATION
# 1654                                     Subway Surfers           GAME
# 1655                                   Candy Crush Saga           GAME
# 1660                                       Clash Royale           GAME
# 1670                                     Clash of Clans           GAME
# 1700                                     Subway Surfers           GAME
# 1704                                     Clash of Clans           GAME
# 1705                                   Candy Crush Saga           GAME
# 1721                                       Clash Royale           GAME
# ...

# %%
dfplay1.drop(columns = 'High_reviews',inplace = True)

# %%
dfplay1[dfplay1['Price']>200].shape
# Out:
# (17, 13)

# %%
B= dfplay1[dfplay1['Price']>200]

# %%
B['Genres'].value_counts()
# Out:
# Finance          7
# Lifestyle        6
# Entertainment    4
# Name: Genres, dtype: int64

# %%
filter_list = ['Finance', 'Lifestyle', 'Entertainment']

# %%
dfplay1[dfplay1.Genres.isin(filter_list)].median()
# Out:
# Rating          4.3
# Reviews       497.0
# Size        12000.0
# Installs    50000.0
# Price           0.0
# dtype: float64

# %%
C = dfplay1[dfplay1.Genres.isin(filter_list)]

# %%
C['Type'].value_counts()
# Out:
# Free    1315
# Paid      55
# Name: Type, dtype: int64

# %%
C[C['Type'] == 'Paid' ].median()
# Out:
# Rating         4.30
# Reviews       93.00
# Size        4000.00
# Installs    1000.00
# Price          4.99
# dtype: float64

# %%
dfplay1['Price'] = np.where(dfplay1['Price'] > 200 , 4.99 , dfplay1['Price'])

# %%
dfplay1['Price'] = np.where(dfplay1['Price'] == 200 , 4.99 , dfplay1['Price'])

# %%
dfplay1.quantile(q=[.25,.5,.75,.9,.95,.99],axis=0)
# Out:
#       Rating     Reviews     Size     Installs  Price
# 0.25     4.1       38.00   5000.0       3000.0   0.00
# 0.50     4.3     2094.00  13000.0     100000.0   0.00
# 0.75     4.5    51789.00  26000.0    5000000.0   0.00
# 0.90     4.7   423947.40  50000.0   10000000.0   0.00
# 0.95     4.8  1312126.90  69000.0   50000000.0   1.99
# 0.99     5.0  7167453.26  96000.0  500000000.0   7.99

# %%
dfplay1[dfplay1['Installs']> 50000000 ]
# Out:
#                                           App             Category  Rating  \
# 139                      Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6
# 143                             Amazon Kindle  BOOKS_AND_REFERENCE     4.2
# 152                         Google Play Books  BOOKS_AND_REFERENCE     3.9
# 194    OfficeSuite : Free Office + PDF Editor             BUSINESS     4.3
# 293    OfficeSuite : Free Office + PDF Editor             BUSINESS     4.3
# ...                                       ...                  ...     ...
# 10186                        Farm Heroes Saga               FAMILY     4.4
# 10253  File Commander - File Manager/Explorer             BUSINESS     4.3
# 10327                        Garena Free Fire                 GAME     4.5
# 10647                       Motorola FM Radio        VIDEO_PLAYERS     3.9
# 10707          Photo Editor Collage Maker Pro          PHOTOGRAPHY     4.5
#
#        Reviews     Size    Installs  Type  Price Content Rating  \
# ...

# %%
sns.set(rc={'figure.figsize':(10,7)})

# %%
sns.boxplot(dfplay1['Installs'],orient='v')

# %%
sns.boxplot(dfplay1['Reviews'],orient='v')

# %%
I = dfplay1[dfplay1['Installs']> 50000000 ]

# %%
I['Category'].value_counts()
# Out:
# GAME                   157
# COMMUNICATION           75
# PRODUCTIVITY            52
# PHOTOGRAPHY             42
# TOOLS                   37
# FAMILY                  33
# SOCIAL                  31
# SHOPPING                19
# TRAVEL_AND_LOCAL        15
# PERSONALIZATION         14
# VIDEO_PLAYERS           14
# ENTERTAINMENT           11
# NEWS_AND_MAGAZINES      10
# BOOKS_AND_REFERENCE      7
# FINANCE                  4
# SPORTS                   4
# MAPS_AND_NAVIGATION      4
# EDUCATION                4
# BUSINESS                 3
# HEALTH_AND_FITNESS       2
# LIFESTYLE                1
# Name: Category, dtype: int64

# %%
filter_list = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'PHOTOGRAPHY', 'TOOLS' , 'FAMILY' , 'SOCIAL' , 'SHOPPING' , 'TRAVEL_AND_LOCAL' , 'VIDEO_PLAYERS' ,'PERSONALIZATION' , 'ENTERTAINMENT ' , 'NEWS_AND_MAGAZINES' , 'BOOKS_AND_REFERENCE' , 'SPORTS' ]

# %%
dfplay1[dfplay1.Category.isin(filter_list)].median()
# Out:
# Rating           4.3
# Reviews       3845.0
# Size         13000.0
# Installs    100000.0
# Price            0.0
# dtype: float64

# %%
dfplay1['Installs'] = np.where(dfplay1['Installs'] > 50000000 , 100000 , dfplay1['Installs'])

# %%
dfplay1[dfplay1['Installs']> 50000000 ]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
R = dfplay1[dfplay1['Reviews']> 1312126 ]

# %%
dfplay1['Reviews'] = np.where(dfplay1['Reviews'] > 1312126 , 3845 , dfplay1['Reviews'])

# %%
 dfplay1[(dfplay1['Reviews']) > (dfplay1['Installs'])]
# Out:
#                                           App             Category  Rating  \
# 143                             Amazon Kindle  BOOKS_AND_REFERENCE     4.2
# 194    OfficeSuite : Free Office + PDF Editor             BUSINESS     4.3
# 293    OfficeSuite : Free Office + PDF Editor             BUSINESS     4.3
# 346              imo beta free calls and text        COMMUNICATION     4.3
# 369                          Android Messages        COMMUNICATION     4.2
# ...                                       ...                  ...     ...
# 8628                              Google Docs         PRODUCTIVITY     4.3
# 8636                              Google Keep         PRODUCTIVITY     4.4
# 8758                  Anti-virus Dr.Web Light                TOOLS     4.5
# 9844                              Google News   NEWS_AND_MAGAZINES     3.9
# 10253  File Commander - File Manager/Explorer             BUSINESS     4.3
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
dfplay1['Correct_reviews'] = np.where(dfplay1['Reviews'] > dfplay1['Installs'] , 'Incorrect' , 'Correct')

# %%
dfplay1['Correct_reviews'].value_counts()
# Out:
# Correct      10749
# Incorrect       90
# Name: Correct_reviews, dtype: int64

# %%
dfplay1[dfplay1["Correct_reviews"] == 'Incorrect']
# Out:
#                                           App             Category  Rating  \
# 143                             Amazon Kindle  BOOKS_AND_REFERENCE     4.2
# 194    OfficeSuite : Free Office + PDF Editor             BUSINESS     4.3
# 293    OfficeSuite : Free Office + PDF Editor             BUSINESS     4.3
# 346              imo beta free calls and text        COMMUNICATION     4.3
# 369                          Android Messages        COMMUNICATION     4.2
# ...                                       ...                  ...     ...
# 8628                              Google Docs         PRODUCTIVITY     4.3
# 8636                              Google Keep         PRODUCTIVITY     4.4
# 8758                  Anti-virus Dr.Web Light                TOOLS     4.5
# 9844                              Google News   NEWS_AND_MAGAZINES     3.9
# 10253  File Commander - File Manager/Explorer             BUSINESS     4.3
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
dfplay1['Reviews'] = np.where(dfplay1['Correct_reviews'] == 'Incorrect', dfplay1['Installs'], dfplay1['Reviews'])

# %%
dfplay1[dfplay1["Correct_reviews"] == 'Incorrect']
# Out:
#                                           App             Category  Rating  \
# 143                             Amazon Kindle  BOOKS_AND_REFERENCE     4.2
# 194    OfficeSuite : Free Office + PDF Editor             BUSINESS     4.3
# 293    OfficeSuite : Free Office + PDF Editor             BUSINESS     4.3
# 346              imo beta free calls and text        COMMUNICATION     4.3
# 369                          Android Messages        COMMUNICATION     4.2
# ...                                       ...                  ...     ...
# 8628                              Google Docs         PRODUCTIVITY     4.3
# 8636                              Google Keep         PRODUCTIVITY     4.4
# 8758                  Anti-virus Dr.Web Light                TOOLS     4.5
# 9844                              Google News   NEWS_AND_MAGAZINES     3.9
# 10253  File Commander - File Manager/Explorer             BUSINESS     4.3
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
dfplay1.drop(columns = 'Correct_reviews',inplace = True)

# %%
dfplay1.quantile(q=[.25,.5,.75,.9,.95,.99],axis=0)
# Out:
#       Rating   Reviews     Size    Installs  Price
# 0.25     4.1      38.0   5000.0      3000.0   0.00
# 0.50     4.3    2094.0  13000.0    100000.0   0.00
# 0.75     4.5   29996.0  26000.0   1000000.0   0.00
# 0.90     4.7  172390.4  50000.0  10000000.0   0.00
# 0.95     4.8  361799.0  69000.0  10000000.0   1.99
# 0.99     5.0  946926.0  96000.0  50000000.0   7.99

# %%
sns.boxplot(dfplay1['Installs'],orient='v')

# %%
sns.boxplot(dfplay1['Reviews'],orient='v')

# %%
import matplotlib.pyplot as plt

# %%
sns.distplot(dfplay1['Rating'].dropna(),kde=True,color='darkred',bins=5)

# %%
sns.distplot(dfplay1['Size'].dropna(),kde=True,color='darkred',bins=5)

# %%
sns.jointplot(x='Rating',y='Price',data=dfplay1)

# %%
sns.jointplot(x='Rating',y='Size',data=dfplay1)

# %%
sns.jointplot(x='Rating',y='Reviews',data=dfplay1)

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.boxplot(x="Rating", y="Content Rating", data=dfplay1,palette='rainbow')

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.boxplot(x="Rating", y="Category", data=dfplay1,palette='rainbow')

# %%
# sns.boxplot(x="Rating", y="Category", data=dfplay1,palette='rainbow')

# %%
sns.set(rc={'figure.figsize':(10,5)},font_scale=1.3)

# %%
sns.heatmap(dfplay1.corr(),annot=True,cmap='viridis')

# %% [markdown]
# # Sample Output post running ML¶

# %%
### DEFINE THE INDEPENDENT VARIABLES
### y = mx + b
X = dfplay1[['Installs', 'Reviews', 'Size']]


### DEFINE THE DEPENDENT VARIABLE
y = dfplay1['Rating']

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.shape
# Out:
# (10839, 3)

# %%
X.shape[0]
# Out:
# 10839

# %%
X.shape[1]
# Out:
# 3

# %%
X.values
# Out:
# array([[1.00000e+04, 1.59000e+02, 1.90000e+04],
#        [5.00000e+05, 9.67000e+02, 1.40000e+04],
#        [5.00000e+06, 8.75100e+04, 8.00000e+03],
#        ...,
#        [1.00000e+03, 3.00000e+00, 9.00000e+03],
#        [1.00000e+03, 1.14000e+02, 1.30000e+04],
#        [1.00000e+07, 3.98307e+05, 1.90000e+04]])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif
# Out:
#    VIF Factor  features
# 0    1.732664  Installs
# 1    1.774841   Reviews
# 2    1.145106      Size

# %% [markdown]
# # STEP 4 MODEL BUILDING & FITTING THE MODEL USING TRAINING DATA

# %%
#### split the data into training and testing data using sci kit learn
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size = 0.30,random_state=5)

# %%
### training the model on linear regression
### sklearn.linear_model, LinearRegression will have the linear equation y=mx+b
from sklearn.linear_model import LinearRegression

# %%
#fitting our model to train and test
### instantiate an instance of linear regression object
#### fit is used for fitting the model to training data . only on training data

lm = LinearRegression()

### MODELFITSTRAIN - use the LinearRegression() function on my training data 
lm.fit(X_train,y_train) #### no need to set this to any variable. its inplace.

### LinearRegression.fit(x_train,y_train)  -- this is also correct

#### we get an output stating that the linear regression model has been trained
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
type(lm)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
print(lm.intercept_)
# Out:
# 4.169236243892378

# %%
### to view the coefficients of the linear model- my independent variables - "m"
lm.coef_
# Out:
# array([5.39236135e-10, 3.44634685e-07, 8.01227582e-07])

# %% [markdown]
# # STEP 4 MODEL PREDICTION AND VISUALIZATION OF PREDICTED OUTPUT

# %%
### MODEL PREDICTS TEST (MPT)

pred_y = lm.predict(X_test)

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
### Visualtion of predictive results
plt.scatter(y_test,pred_y,color='green',cmap='viridis')

plt.xlabel('Y Actual') 
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
sns.regplot(y_test,pred_y)

# %%
### DISTRIBUTION OF 
sns.distplot((y_test-pred_y))

# %%
## import the sklearn metrics package
from sklearn import metrics

# %%
from sklearn.metrics import r2_score

# %%
### run mean absolute error between actual y (y_test) and predicted y (pred_y)
metrics.mean_absolute_error(y_test,pred_y)
# Out:
# 0.32474677232852445

# %%
metrics.mean_squared_error(y_test,pred_y)
# Out:
# 0.22999130491980216

# %%
#### RMSE -   between actual y (y_test) and predicted y (pred_y)

np.sqrt(metrics.mean_squared_error(y_test,pred_y))

### when RMSE is less than one, this typically means that your model has good accuracy
# Out:
# 0.47957408699782994

# %%
lm.score(X_test,y_test)
# Out:
# 0.013009854609602356

# %%
### calculate variance. Closer the value is to 1 ,  higher is the model accuracy
lm.score(X_test,y_test)
# Out:
# 0.013009854609602356

# %%
### training accuracy
lm.score(X_train,y_train)
# Out:
# 0.01834304609985793

# %%
r2_score(y_test,pred_y)
# Out:
# 0.013009854609602356

# %% [markdown]
# ### r2 score is very low , need to try different models now

# %% [markdown]
# # MODEL 2

# %%
### DEFINE THE INDEPENDENT VARIABLES
### y = mx + b
X1 = dfplay1[[ 'Reviews', 'Size']]


### DEFINE THE DEPENDENT VARIABLE
y1 = dfplay1['Rating']

# %%
X1_train, X1_test, y1_train, y1_test =train_test_split(X1,y1, test_size = 0.30,random_state=5)

# %%
#fitting our model to train and test
### instantiate an instance of linear regression object
#### fit is used for fitting the model to training data . only on training data

lm1 = LinearRegression()

### MODELFITSTRAIN - use the LinearRegression() function on my training data 
lm1.fit(X1_train,y1_train) #### no need to set this to any variable. its inplace.

### LinearRegression.fit(x_train,y_train)  -- this is also correct

#### we get an output stating that the linear regression model has been trained
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm1.intercept_)
# Out:
# 4.169779538232121

# %%
pred_y1 = lm1.predict(X1_test)

# %%
### Visualtion of predictive results
plt.scatter(y1_test,pred_y1,color='green',cmap='viridis')
plt.xlabel('Y Actual') 
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
sns.regplot(y1_test,pred_y1)

# %%
metrics.mean_absolute_error(y1_test,pred_y1)
# Out:
# 0.3246615648088135

# %%
metrics.mean_squared_error(y1_test,pred_y1)
# Out:
# 0.23001329617706287

# %%
#### RMSE -   between actual y (y_test) and predicted y (pred_y)

np.sqrt(metrics.mean_squared_error(y1_test,pred_y1))

### when RMSE is less than one, this typically means that your model has good accuracy
# Out:
# 0.47959701435378316

# %%
lm1.score(X1_test,y1_test)
# Out:
# 0.012915480806172443

# %%
lm1.score(X1_train,y1_train)
# Out:
# 0.01828440248810448

# %%
r2_score(y1_test,pred_y1)
# Out:
# 0.012915480806172441

# %% [markdown]
# ### r2 score is very low , need to try different models now

# %% [markdown]
# # Model 3

# %%
### DEFINE THE INDEPENDENT VARIABLES
### y = mx + b
X2 = dfplay1[[ 'Reviews', 'Size' , 'Price']]


### DEFINE THE DEPENDENT VARIABLE
y2 = dfplay1['Rating']

# %%
vif = pd.DataFrame()

vif["VIF Factor"] = [variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])]
vif["features"] = X2.columns
vif
# Out:
#    VIF Factor features
# 0    1.129421  Reviews
# 1    1.137685     Size
# 2    1.008101    Price

# %%
X2_train, X2_test, y2_train, y2_test =train_test_split(X2,y2, test_size = 0.30,random_state=5)

# %%
#fitting our model to train and test
### instantiate an instance of linear regression object
#### fit is used for fitting the model to training data . only on training data

lm2 = LinearRegression()

### MODELFITSTRAIN - use the LinearRegression() function on my training data 
lm2.fit(X2_train,y2_train) #### no need to set this to any variable. its inplace.

### LinearRegression.fit(x_train,y_train)  -- this is also correct

#### we get an output stating that the linear regression model has been trained
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm2.intercept_)
# Out:
# 4.168244417729233

# %%
lm2.coef_
# Out:
# array([3.63548201e-07, 8.04910343e-07, 3.35189100e-03])

# %%
pred_y2 = lm2.predict(X2_test)

# %%
### Visualtion of predictive results
plt.scatter(y2_test,pred_y2,color='green',cmap='viridis')

plt.xlabel('Y Actual') 
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
sns.regplot(y2_test,pred_y2)

# %%
metrics.mean_absolute_error(y2_test,pred_y2)
# Out:
# 0.32474297134044494

# %%
metrics.mean_squared_error(y2_test,pred_y2)
# Out:
# 0.22997135617533337

# %%
#### RMSE -   between actual y (y_test) and predicted y (pred_y)

np.sqrt(metrics.mean_squared_error(y2_test,pred_y2))

### when RMSE is less than one, this typically means that your model has good accuracy
# Out:
# 0.4795532881498503

# %%
### calculate variance. Closer the value is to 1 ,  higher is the model accuracy
lm2.score(X2_test,y2_test)
# Out:
# 0.013095463125152305

# %%
### training accuracy
lm2.score(X2_train,y2_train)
# Out:
# 0.018812840543293463

# %%
r2_score(y2_test,pred_y2)
# Out:
# 0.013095463125152307

# %% [markdown]
# ### r2 score is very low , need to try different models now

# %% [markdown]
# # Model 4

# %%
### DEFINE THE INDEPENDENT VARIABLES
### y = mx + b
X3 = dfplay1[[ 'Installs', 'Size' , 'Price']]


### DEFINE THE DEPENDENT VARIABLE
y3 = dfplay1['Rating']

# %%
vif = pd.DataFrame()

vif["VIF Factor"] = [variance_inflation_factor(X3.values, i) for i in range(X3.shape[1])]
vif["features"] = X3.columns
vif
# Out:
#    VIF Factor  features
# 0    1.102492  Installs
# 1    1.110566      Size
# 2    1.008019     Price

# %%
X3_train, X3_test, y3_train, y3_test =train_test_split(X3,y3, test_size = 0.30,random_state=5)

# %%
#fitting our model to train and test
### instantiate an instance of linear regression object
#### fit is used for fitting the model to training data . only on training data

lm3 = LinearRegression()

### MODELFITSTRAIN - use the LinearRegression() function on my training data 
lm3.fit(X3_train,y3_train) #### no need to set this to any variable. its inplace.

### LinearRegression.fit(x_train,y_train)  -- this is also correct

#### we get an output stating that the linear regression model has been trained
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm3.intercept_)
# Out:
# 4.172475021848587

# %%
lm3.coef_
# Out:
# array([4.54157792e-09, 1.03212367e-06, 3.05689451e-03])

# %%
pred_y3 = lm3.predict(X3_test)

# %%
### Visualtion of predictive results
plt.scatter(y3_test,pred_y3,color='green',cmap='viridis')

plt.xlabel('Y Actual') 
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
sns.regplot(y3_test,pred_y3)

# %%
metrics.mean_absolute_error(y3_test,pred_y3)
# Out:
# 0.32422547645472016

# %%
metrics.mean_squared_error(y3_test,pred_y3)
# Out:
# 0.23117889417772106

# %%
#### RMSE -   between actual y (y_test) and predicted y (pred_y)

np.sqrt(metrics.mean_squared_error(y3_test,pred_y3))

### when RMSE is less than one, this typically means that your model has good accuracy
# Out:
# 0.48081066354410346

# %%
### calculate variance. Closer the value is to 1 ,  higher is the model accuracy
lm3.score(X3_test,y3_test)
# Out:
# 0.007913405877567947

# %%
### training accuracy
lm3.score(X3_train,y3_train)
# Out:
# 0.00950061822673176

# %%
r2_score(y3_test,pred_y3)
# Out:
# 0.007913405877567947

# %% [markdown]
# ## For all the 4 Models RMSE is less than one, this typically means that model has good accuracy But r2 score is very less
# ## than 1 , this means prediction accuracy is not well enough . So Need more data to run accurate Model
